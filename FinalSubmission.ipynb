# %%
pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple/ arms-fda-module
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple/
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import arms_fda_module

# %%
#assign values to variables

key = '91ycY1QG2K2gtDXnvHqwB1EvpN8WdKVGEBTLPZSf'

year = ['2000','2001','2002','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']

variable = ['kount','crop']

category = ['age']

report = ['3']

farmtype = 'all farms'

statecode = ['12','13']

# %%
#Get a dictionary containing results FDA's ARMS API 

b = getjson_fda_arms(key,year,variable,statecode,category,report,farmtype)

type(b)
# Out:
# dict

# %%
#Get a Pandas dataframe from transforming FDA's ARMS API

a = getdf_fda_arms(key,year,variable,statecode,category,report,farmtype)
print(a)
# Out:
#       year    state                          report   farmtype      category  \
# 0     2005  Florida  Farm Business Financial Ratios  All Farms  Operator Age
# 1     2006  Florida  Farm Business Financial Ratios  All Farms  Operator Age
# 2     2008  Florida  Farm Business Financial Ratios  All Farms  Operator Age
# 3     2010  Florida  Farm Business Financial Ratios  All Farms  Operator Age
# 4     2011  Florida  Farm Business Financial Ratios  All Farms  Operator Age
# ...    ...      ...                             ...        ...           ...
# 1865  2014  Georgia  Farm Business Financial Ratios  All Farms  Operator Age
# 1866  2015  Georgia  Farm Business Financial Ratios  All Farms  Operator Age
# 1867  2016  Georgia  Farm Business Financial Ratios  All Farms  Operator Age
# 1868  2019  Georgia  Farm Business Financial Ratios  All Farms  Operator Age
# 1869  2020  Georgia  Farm Business Financial Ratios  All Farms  Operator Age
#
# ...

# %%
#prints a list of states for which data is available along with their id
stateid(key)
# Out:
#     id code               name
# 0   00  all  All survey states
# 1   05   ar           Arkansas
# 2   06   ca         California
# 3   12   fl            Florida
# 4   13   ga            Georgia
# 5   17   il           Illinois
# 6   18   in            Indiana
# 7   19   ia               Iowa
# 8   20   ks             Kansas
# 9   27   mn          Minnesota
# 10  29   mo           Missouri
# 11  31   ni           Nebraska
# 12  37   nc     North Carolina
# 13  48   tx              Texas
# 14  53   wa         Washington
# 15  55   wi          Wisconsin

# %%
#prints a list of farms types for which data is available
farmtype(key)
# Out:
#    id                      name  desc  is_invalid
# 0   1                 All Farms  None       False
# 1   2           Farm Businesses  None       False
# 2   3  Farm Operator Households  None       False

# %%
#plots a time series by category when you input the output from the getdf_fda_arms() function

plotseries_cat(df=a,variable_id='freconum',state='Florida')

# %%
#prints results of a time series regression and plots the regression

timesseries_regplot(df=a,variable_id='kount',state='Florida',category_value = '34 years or younger')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               estimate   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                 -0.041
# Method:                 Least Squares   F-statistic:                    0.3699
# Date:                Thu, 15 Dec 2022   Prob (F-statistic):              0.552
# Time:                        13:58:01   Log-Likelihood:                -126.27
# No. Observations:                  17   AIC:                             256.5
# Df Residuals:                      15   BIC:                             258.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     2.7e+04   4.32e+04      0.625      0.541    -6.5e+04    1.19e+05
# ...
